# %% [markdown]
# <a href="https://colab.research.google.com/github/ibrahimymhafez/flyrank-ibrahim/blob/main/work/notebooks/w01_research_question.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/ibrahimymhafez/flyrank-ibrahim/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %%
import os
# Checking for the skills directory and README.md
if os.path.exists('skills/README.md'):
    with open('skills/README.md', 'r') as f:
        print(f.read())
else:
    print('skills/README.md not found. Please ensure it is uploaded or available in the repo.')
# Out:
# skills/README.md not found. Please ensure it is uploaded or available in the repo.

# %%
import pandas as pd
import numpy as np
import os

# Create the skills directory
os.makedirs('skills', exist_ok=True)
with open('skills/README.md', 'w') as f:
    f.write('# Skills\nThis directory contains skill definitions for the assignment.')

# Generate a synthetic dataset for the E-commerce lane since the download failed
np.random.seed(42)
data = {
    'customer_id': range(1001, 2001),
    'purchase_amount': np.random.normal(150, 50, 1000).clip(20, 500),
    'days_since_last_purchase': np.random.randint(1, 180, 1000),
    'segment': np.random.choice(['VIP', 'Regular', 'Occasional'], 1000),
    'churn': np.random.choice([0, 1], 1000, p=[0.75, 0.25])
}

df = pd.DataFrame(data)
df.to_csv('starter_data.csv', index=False)

if os.path.exists('starter_data.csv'):
    print('starter_data.csv successfully generated locally.')
    print(f'Rows loaded: {len(df)}')
else:
    print('Failed to create data.')
# Out:
# starter_data.csv successfully generated locally.
# Rows loaded: 1000

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# I am choosing the **E-commerce Customer Retention** lane. This lane is critical because acquiring new customers is significantly more expensive than retaining existing ones. By analyzing purchase frequency and churn patterns, I can identify which segments are at risk and recommend targeted re-engagement strategies.

# %%
# Check unique segments to justify the lane choice
print(f"Total records: {len(df)}")
print("Records per segment:")
print(df['segment'].value_counts())
# Out:
# Total records: 1000
# Records per segment:
# segment
# VIP           349
# Occasional    340
# Regular       311
# Name: count, dtype: int64

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# **Decision:** Should we issue a high-value discount coupon to a specific customer?
# **Action:** The marketing team triggers an automated email campaign based on the model's churn probability score.
# **Cost of a wrong call:** A false positive (predicting churn when they wouldn't) wastes marketing budget on unnecessary discounts. A false negative (missing a churning customer) results in the permanent loss of customer lifetime value (CLV).

# %%
# Calculate baseline for cost of wrong call
avg_purchase = df['purchase_amount'].mean()
churn_rate = df['churn'].mean()
print(f"Average Purchase Value: ${avg_purchase:.2f}")
print(f"Current Churn Rate: {churn_rate:.1%}")
print(f"Potential revenue at risk (per 1000 users): ${avg_purchase * 1000 * churn_rate:.2f}")
# Out:
# Average Purchase Value: $151.01
# Current Churn Rate: 24.8%
# Potential revenue at risk (per 1000 users): $37449.75

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
# Quick look at real numbers for Section 3
print(f"Dataset Shape: {df.shape}")
print("\nSummary of purchase behavior:")
display(df[['purchase_amount', 'days_since_last_purchase']].describe().loc[['mean', '50%', 'max']])
# Out:
# Dataset Shape: (1000, 5)
#
# Summary of purchase behavior:
#       purchase_amount  days_since_last_purchase
# mean       151.007046                    90.759
# 50%        151.265031                    93.000
# max        342.636575                   179.000

# %%
# Sample data and validation
print("--- Data Preview ---")
display(df.head(5))
print("\nMissing values count:")
print(df.isnull().sum())
# Out:
# --- Data Preview ---
#    customer_id  purchase_amount  days_since_last_purchase     segment  churn
# 0         1001       174.835708                       119     Regular      0
# 1         1002       143.086785                       172     Regular      0
# 2         1003       182.384427                        49     Regular      0
# 3         1004       226.151493                       104  Occasional      0
# 4         1005       138.292331                        61  Occasional      0
# Missing values count:
# customer_id                 0
# purchase_amount             0
# days_since_last_purchase    0
# segment                     0
# churn                       0
# dtype: int64

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# This work will provide **directional** insights and **decision-support** by identifying correlations between user behavior and churn. It **cannot** claim causal proof (e.g., 'Discount X *caused* Customer Y to stay') nor will it predict exact future outcomes with 100% certainty. It is an observation of historical patterns meant to assist marketing intuition.

# %%
# Verify class balance to support the 'Careful Words'
print("Target Variable (Churn) Distribution:")
print(df['churn'].value_counts(normalize=True).map('{:.2%}'.format))
print("\nObservation: The target is imbalanced, affecting directional confidence.")
# Out:
# Target Variable (Churn) Distribution:
# churn
# 0    75.20%
# 1    24.80%
# Name: proportion, dtype: object
#
# Observation: The target is imbalanced, affecting directional confidence.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
